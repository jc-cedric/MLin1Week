# %% [markdown]
# # Logistic Regression #

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.linear_model import SGDClassifier

# %%
# random data generation: 100 samples, 2 classes, 2 features x0 and x1
np.random.seed(1)
X, y = make_classification(n_samples=100, n_features=2, n_redundant=0, n_informative=1, n_clusters_per_class=1)

# %%
# Data visualisation
plt.figure(num=None, figsize=(8,6))
plt.scatter(X[:,0], X[:,1], marker = 'o', c=y,edgecolors ='k')
plt.xlabel('X0')
plt.ylabel('X1')
X.shape
# Out:
# (100, 2)

# %%
# model generation using cost function 'log' for Logistic Regression
model = SGDClassifier(max_iter=1000, eta0=0.001, loss='log')


model.fit(X,y)
print('score: ', model.score(X,y))
# Out:
# score:  1.0

# %%
# Data visualisation
h = .02
colors="bry"
x_min, x_max = X[:,0].min() - 1, X[:,0].max() + 1
y_min, y_max = X[:,1].min() - 1, X[:,1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
plt.axis('tight')

for i, color in zip(model.classes_, colors):
    idx = np.where(y == i)
    plt.scatter(X[idx, 0], X[idx, 1], c=color, cmap=plt.cm.Paired, edgecolor='black', s=20)
